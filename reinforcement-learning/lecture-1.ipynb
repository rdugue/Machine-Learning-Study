# %% [markdown]
# **Task**: Complete the Python class structure below to define the MDP environment parameters.
#
# **Coding Exercise**: Modeling the Student Tutor MDP
# Based on the "Student Tutor" example discussed in the sources, your task is to define the components of a Markov Decision Process for an AI agent teaching a student addition and subtraction.
# The Scenario:
# * Topics: Addition (Easy) and Subtraction (Hard).
# * Actions: The agent can give an "Addition Problem" or a "Subtraction Problem".
# * Feedback: Student gets it right (+1 reward) or wrong (-1 reward).
#
#  5. Conceptual Question:
#  If a policy optimizes for the "expected discounted sum of rewards" in this specific setup,
#  what "reward hacking" behavior might emerge? [28, 29]
#  Answer: _________________________________________________

# %%
class StudentTutorMDP:
    def __init__(self):
        # 1. Define the Action Space [27]
        self.actions = ["addition_prob", "subtraction_prob"]
        
        # 2. Define a possible State Space representation 
        # Hint: Consider a vector representing mastery of both topics [24]
        self.states = [] # Fill in your conceptual representation
        
    def reward_model(self, student_correct):
        # 3. Implement the reward logic described in the lecture [23]
        if student_correct:
            return 1
        else:
            return -1

    def dynamics_model(self, current_state, action):
        # 4. Describe (in a comment) how the state might change [28]
        # Example: Giving an addition problem might increase the 
        # probability of addition mastery in the next state.
        pass
